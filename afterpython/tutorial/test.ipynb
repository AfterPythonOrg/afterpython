# %% [markdown]
# [![Open in molab](https://marimo.io/molab-shield.svg)](https://molab.marimo.io/github/AfterPythonOrg/afterpython/blob/main/afterpython/tutorial/test.ipynb)

# %%
print('test')
# Out:
# test
